# %%
import logging
import time
from datetime import datetime
import os
import ast
import codecs
import json
import collections
import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid
import random
import fasttext
import string
from gensim.models import KeyedVectors
from tqdm import tqdm_notebook as tqdm
from ruwordnet import RuWordNet

FORMAT = "%(asctime)s %(levelname)s: %(message)s"
logging.basicConfig(level=logging.DEBUG,format=FORMAT)

from utils import save_to_file, PUNCT_SYMBOLS, PREPOSITIONS, RESTRICT_TAGS, \
                  get_top, get_top_hyperomyns_counter, get_top_hyperomyns_counter_v, \
                  read_train_dataset, read_train_dataset, read_gold_dataset, \
                  normalize_ma, get_synset_str_and_vector, get_synset_words

# %%
import pymorphy2
morph_analyzer = pymorphy2.MorphAnalyzer()
# Out:
# 2020-03-23 20:51:48,214 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:51:48,269 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168

# %% [markdown]
# ### GRID PROCESS

# %%
common_prefix = 'lower_true'

# %%
results_dir = 'results/res_'+common_prefix

# %%
! mkdir -p {results_dir}

# %%
def params_grid():
    norm_functions = [normalize_ma]
    norm_fn_out_of_vocab2synonym = [None]
    norm_fn_sort   = [False]
    norm_fn_unique = [False] 
    norm_fn_lower  = [True]
    norm_fn_min_word_len = [1]

    punct_symbols = set(PUNCT_SYMBOLS).copy()
    punct_symbols_ = punct_symbols
    
    # special symbols from ruwordnet
    from_ruwordnet_punct_symbols = {'—', '«', '»', '·', '\xad', '\xa0', '°', '–', '§'} 
    
    punct_symbols.update(from_ruwordnet_punct_symbols)
    
    norm_fn_punct_symbols = [punct_symbols]
    norm_fn_prepositions  = [PREPOSITIONS]
    norm_fn_restrict_tags = [RESTRICT_TAGS]

    #verb_tags = ['VERB', 'INFN', 'GRND', 'NOUN']
    norm_fn_accept_tags = [None]

#     p1_l = [-1.0, 0.0, 0.1, 0.5, 1.0, 2.0]
#     p1_l = [0.0, 0.1, 1.0]
    p1_l = [0.1]
#     p2_l = [-1.0, 0.0, 0.1, 0.5, 1.0, 2.0]
#     p2_l = [0.0, 0.1, 1.0]
    p2_l = [1.0]
#     p3_l = [-1.0, 0.0, 0.1, 0.5, 1.0, 2.0]
#     p3_l = [0.0, 0.1, 1.0]
    p3_l = [1.0]
#     k_l  = [1, 3, 5, 7, 10, 15, 20]
    k_l  = [10]
#     topn_l = [1, 3, 5, 7, 10, 15, 20]
    topn_l  = [10]
    account_gold_l = [False]
    
    all_params = {'p1': p1_l,
                  'p2': p2_l,
                  'p3': p3_l,
                  'k' : k_l, 
                  'topn': topn_l,
                  'account_gold': account_gold_l,
                  
                  'normalize_func': norm_functions,
                  
                  'out_of_vocab2synonym': norm_fn_out_of_vocab2synonym,
                  'sort': norm_fn_sort,
                  'unique': norm_fn_unique,
                  'lower': norm_fn_lower,
                  'min_word_len': norm_fn_min_word_len,
                  'punct_symbols': norm_fn_punct_symbols,
                  'prepositions': norm_fn_prepositions,
                  'restrict_tags': norm_fn_restrict_tags,
                  'accept_tags': norm_fn_accept_tags,
                  'ma': [morph_analyzer]
                 }
    
    
    
    for p in ParameterGrid(all_params):
        yield p
        
len([params for params in tqdm(params_grid())])
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# 1

# %%
params = list(params_grid())[0]
params
# Out:
# {'accept_tags': None,
#  'account_gold': False,
#  'k': 10,
#  'lower': True,
#  'ma': <pymorphy2.analyzer.MorphAnalyzer at 0x7f7ebcb47710>,
#  'min_word_len': 1,
#  'normalize_func': <function utils.normalize_ma(sentence, out_of_vocab2synonym=None, sort=False, unique=False, punct_symbols=None, lower=True, ma=None, restrict_tags=None, accept_tags=None, min_word_len=0, *args, **kwargs)>,
#  'out_of_vocab2synonym': None,
#  'p1': 0.1,
#  'p2': 1.0,
#  'p3': 1.0,
#  'prepositions': {'в',
#   'да',
#   'для',
#   'до',
#   'и',
#   'из-за',
#   'или',
#   'к',
#   'как',
#   'ли',
#   'либо',
#   'на',
#   'не',
#   'но',
#   'о',
#   'от',
#   'перед',
#   'по',
#   'под',
#   'при',
#   'с',
#   'так',
#   'то',
#   'только'},
#  'punct_symbols': {'!',
#   '"',
#   '#',
#   '$',
#   '%',
#   '&',
#   "'",
#   '(',
#   ')',
#   '*',
#   '+',
#   ',',
#   '-',
#   '.',
#   '/',
#   ':',
#   ';',
#   '<',
#   '=',
#   '>',
#   '?',
#   '@',
#   '[',
#   '\\',
#   ']',
#   '^',
#   '_',
#   '`',
#   '{',
#   '|',
#   '}',
#   '~',
#   '\xa0',
#   '§',
#   '«',
#   '\xad',
#   '°',
#   '·',
#   '»',
#   '–',
#   '—'},
#  'restrict_tags': {'CONJ', 'INTJ', 'NPRO', 'PRCL', 'PRED', 'PREP'},
#  'sort': False,
#  'topn': 10,
#  'unique': False}

# %%
### LOADING DATA

# %%
# %%time
ruwordnet = RuWordNet('data/ruwordnet')
# Out:
# 2020-03-23 20:51:48,431 DEBUG: Trying to load tree from data/ruwordnet/composed_of.xml
# 2020-03-23 20:51:49,264 DEBUG: Trying to load tree from data/ruwordnet/senses.A.xml
# 2020-03-23 20:51:49,377 DEBUG: Trying to load tree from data/ruwordnet/senses.N.xml
# 2020-03-23 20:51:49,884 DEBUG: Trying to load tree from data/ruwordnet/senses.V.xml
# 2020-03-23 20:51:50,095 DEBUG: Trying to load tree from data/ruwordnet/synsets.A.xml
# 2020-03-23 20:51:50,233 DEBUG: Trying to load tree from data/ruwordnet/synsets.N.xml
# 2020-03-23 20:51:50,460 DEBUG: Trying to load tree from data/ruwordnet/synsets.V.xml
# 2020-03-23 20:51:50,527 DEBUG: Trying to load tree from data/ruwordnet/synset_relations.A.xml
# 2020-03-23 20:51:50,690 DEBUG: Trying to load tree from data/ruwordnet/synset_relations.N.xml
# 2020-03-23 20:51:50,985 DEBUG: Trying to load tree from data/ruwordnet/synset_relations.V.xml
# 2020-03-23 20:51:51,914 INFO: RuWordNet loaded from data/ruwordnet
# CPU times: user 2.76 s, sys: 237 ms, total: 2.99 s
# Wall time: 3.48 s

# %%
# %%time
ft_model_file='fasttext/cc.ru.300.bin'
ft_model = fasttext.load_model(ft_model_file)
# Out:
# CPU times: user 2.94 s, sys: 7.65 s, total: 10.6 s
# Wall time: 36 s
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# %%time
tayga_none_fasttextcbow_300_10_2019='data/rusvectores_models/tayga_none_fasttextcbow_300_10_2019/model.model'
model_tayga = KeyedVectors.load(tayga_none_fasttextcbow_300_10_2019)
# Out:
# 2020-03-23 20:52:27,977 INFO: loading Word2VecKeyedVectors object from data/rusvectores_models/tayga_none_fasttextcbow_300_10_2019/model.model
# 2020-03-23 20:52:27,978 DEBUG: {'uri': 'data/rusvectores_models/tayga_none_fasttextcbow_300_10_2019/model.model', 'mode': 'rb', 'buffering': -1, 'encoding': None, 'errors': None, 'newline': None, 'closefd': True, 'opener': None, 'ignore_ext': False, 'transport_params': None}
# 2020-03-23 20:52:28,141 INFO: loading vectors from data/rusvectores_models/tayga_none_fasttextcbow_300_10_2019/model.model.vectors.npy with mmap=None
# 2020-03-23 20:52:28,180 INFO: loading vectors_ngrams from data/rusvectores_models/tayga_none_fasttextcbow_300_10_2019/model.model.vectors_ngrams.npy with mmap=None
# 2020-03-23 20:52:28,563 INFO: loading vectors_vocab from data/rusvectores_models/tayga_none_fasttextcbow_300_10_2019/model.model.vectors_vocab.npy with mmap=None
# 2020-03-23 20:52:28,599 INFO: setting ignored attribute vectors_ngrams_norm to None
# 2020-03-23 20:52:28,604 INFO: setting ignored attribute vectors_norm to None
# 2020-03-23 20:52:28,604 INFO: setting ignored attribute buckets_word to None
# 2020-03-23 20:52:28,605 INFO: setting ignored attribute vectors_vocab_norm to None
# 2020-03-23 20:52:28,605 INFO: loaded data/rusvectores_models/tayga_none_fasttextcbow_300_10_2019/model.model
# CPU times: user 136 ms, sys: 494 ms, total: 630 ms
# Wall time: 628 ms

# %%
# %%time
araneum_none_fasttextcbow_300_5_2018 = 'data/rusvectores_models/araneum_none_fasttextcbow_300_5_2018/araneum_none_fasttextcbow_300_5_2018.model'
model_araneum = KeyedVectors.load(araneum_none_fasttextcbow_300_5_2018)
# Out:
# 2020-03-23 20:52:28,609 INFO: loading Word2VecKeyedVectors object from data/rusvectores_models/araneum_none_fasttextcbow_300_5_2018/araneum_none_fasttextcbow_300_5_2018.model
# 2020-03-23 20:52:28,610 DEBUG: {'uri': 'data/rusvectores_models/araneum_none_fasttextcbow_300_5_2018/araneum_none_fasttextcbow_300_5_2018.model', 'mode': 'rb', 'buffering': -1, 'encoding': None, 'errors': None, 'newline': None, 'closefd': True, 'opener': None, 'ignore_ext': False, 'transport_params': None}
# 2020-03-23 20:52:29,046 INFO: loading vectors from data/rusvectores_models/araneum_none_fasttextcbow_300_5_2018/araneum_none_fasttextcbow_300_5_2018.model.vectors.npy with mmap=None
# 2020-03-23 20:52:29,087 INFO: loading vectors_ngrams from data/rusvectores_models/araneum_none_fasttextcbow_300_5_2018/araneum_none_fasttextcbow_300_5_2018.model.vectors_ngrams.npy with mmap=None
# 2020-03-23 20:52:29,497 INFO: loading vectors_vocab from data/rusvectores_models/araneum_none_fasttextcbow_300_5_2018/araneum_none_fasttextcbow_300_5_2018.model.vectors_vocab.npy with mmap=None
# 2020-03-23 20:52:29,539 INFO: setting ignored attribute vectors_vocab_norm to None
# 2020-03-23 20:52:29,539 INFO: setting ignored attribute vectors_ngrams_norm to None
# 2020-03-23 20:52:29,540 INFO: setting ignored attribute vectors_norm to None
# 2020-03-23 20:52:29,540 INFO: setting ignored attribute buckets_word to None
# 2020-03-23 20:52:29,540 INFO: loaded data/rusvectores_models/araneum_none_fasttextcbow_300_5_2018/araneum_none_fasttextcbow_300_5_2018.model
# CPU times: user 401 ms, sys: 506 ms, total: 907 ms
# Wall time: 931 ms

# %%
modelname2model = {'ft.cc.ru.300': ft_model,
                   'tayga_none_fasttextcbow_300_10_2019': model_tayga,
                   'araneum_none_fasttextcbow_300_5_2018': model_araneum,
                  }

# %%
# %%time
words, vector = get_synset_str_and_vector(ruwordnet, 
                                          '116365-V', 
                                          dict(), 
                                          {'ruthes_name': True, 
                                           'senses_names': True}, 
                                          norm_function=normalize_ma, 
                                          model=ft_model)
words
# Out:
# 2020-03-23 20:52:29,555 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,573 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,574 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,591 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,592 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,610 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,611 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,631 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,632 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,651 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,652 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,671 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,673 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,692 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,693 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,712 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,713 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,733 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,734 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,754 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,755 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,775 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,776 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,796 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,798 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,818 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# CPU times: user 219 ms, sys: 52.6 ms, total: 271 ms
# Wall time: 264 ms
# ['будить мысль',
#  'чувство',
#  'зажечь',
#  'зажигать',
#  'разжигать',
#  'возжечь',
#  'разжечь',
#  'будить',
#  'пробудить',
#  'разжигаться',
#  'пробуждать',
#  'вдохнуть',
#  'возжигать']

# %%
vector.shape
# Out:
# (300,)

# %%
words, vector = get_synset_str_and_vector(ruwordnet, 
                                                '9577-N', 
                                                dict(), 
                                              {'ruthes_name': True, 
                                               'senses_names': True}, 
                                                norm_function=normalize_ma, 
                                                model=model_tayga)
words
# Out:
# 2020-03-23 20:52:29,829 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,849 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,851 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,871 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# 2020-03-23 20:52:29,872 INFO: Loading dictionaries from /usr/local/lib/python3.7/dist-packages/pymorphy2_dicts/data
# 2020-03-23 20:52:29,892 INFO: format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
# ['конькобежный спорт', 'конькобежный спорт', 'скоростной бег коньках']

# %%
# %%time

nouns=True  # NOUNS
nouns=False # VERBS

p1,p2,p3,k,topn,account_gold,norm_function = params['p1'],params['p2'],params['p3'],\
                                             params['k'],params['topn'],params['account_gold'],\
                                             params['normalize_func']

pos = "N" if nouns else "V"

norm_fn_params_list = {'out_of_vocab2synonym',
                       'sort',
                       'unique',
                       'lower',
                       'min_word_len',
                       'punct_symbols',
                       'prepositions',
                       'restrict_tags',
                       'accept_tags',
                       'ma'
                       }
norm_fn_params = {param_name: params[param_name] 
                  for param_name in norm_fn_params_list
                  if param_name in params}
if nouns:
    make_sentences_params = {'ruthes_name': True,
                             'definition': False,
                             'senses_names': True,
                             'senses_lemmas': False,
                             'senses_main_word': False,
                             'sep': ' '
                            }
else:
    make_sentences_params = {'ruthes_name': True,
                             'definition': True,
                             'senses_names': True,
                             'senses_lemmas': True,
                             'senses_main_word': True,
                             'sep': ' '
                            }

synsetstr2id = dict()
synsetstr2vector = dict()
for synset in ruwordnet.synsets_list:
    if synset['part_of_speech'] != pos:
        continue

    synset_words, vector = get_synset_str_and_vector(ruwordnet, synset['id'], 
                                                     norm_params=norm_fn_params,
                                                     make_sent_params=make_sentences_params,
                                                     norm_function=norm_function,
                                                     model=ft_model)
    synsetstr = ' '.join(synset_words)
    if synsetstr in synsetstr2id:
        logging.error(f"Duplicate synset_str.{synset['id'],synsetstr2id[synsetstr]}:'{synsetstr}'")
    synsetstr2id[synsetstr] = synset['id']
    synsetstr2vector[synsetstr] = vector
# Out:
# CPU times: user 12.4 s, sys: 0 ns, total: 12.4 s
# Wall time: 12.4 s

# %%
synsetstr2id
# Out:
# {'ливень очень сильный проливной дождь дождь льет дождь лить лить лить ведра лить ведро лить льет дождь лить дождь лить': '4223-V',
#  'быть известным слыть быть известным качестве считаться считаться считаться слыть слыть пользоваться известностью пользоваться известность пользоваться прослыть прослыть': '129120-V',
#  'водоснабжение снабжать снабдить водой снабжать водой снабжать вода снабжать снабдить водой снабдить вода снабдить подать воду подать вода подать обеспечивать водой обеспечивать вода обеспечивать обеспечить водой обеспечить вода обеспечить подавать воду подавать вода подавать': '489-V',
#  'сползти спуститься ползком спуститься ползком спуститься ползком спуститься сползать сползать сползти сползти': '114961-V',
#  'печатать воспроизводить напечатать напечатать пропечатывать пропечатывать печатать печатать отпечатать отпечатать отпечатывать отпечатывать допечатывать допечатывать пропечатать пропечатать допечатать допечатать печататься печататься': '114108-V',
#  'выложить откровенно высказать высказывать сообщать всё выложить выложить выкладывать выкладывать': '117621-V',
#  'вообразить ошибочно предположить предполагать думать преимущественно мнимом действительности существующем воображать воображать вообразить вообразить': '118572-V',
#  'пронести миновать опасности беде пронести пронести опасность миновала опасность миновать миновать проносить проносить': '120195-V',
#  'влиять воздействовать воздействовать вызывать изменения каком объекте поведении оказывать влияние оказывать влияние оказывать влиять влиять оказать влияние оказать влияние оказать воздействовать воздействовать повлиять повлиять': '111611-V',
#  'стыдиться испытывать стыд покраснеть покраснеть испытывать стыд испытывать стыд испытывать гореть стыда гореть стыд гореть устыдиться устыдиться покраснеть стыда покраснеть стыд покраснеть краснеть стыда краснеть стыд краснеть постыдиться постыдиться устыжаться устыжаться сгорать стыда сгорать стыд сгорать стыдиться стыдиться застыдиться застыдиться краснеть краснеть сгорать стыда сгорать стыд сгорать': '119961-V',
#  'овладеть стать обладателем взять получить своё распоряжение стать обладателем овладеть овладеть овладевать овладевать': '115075-V',
#  'ткачество изготовлять материал ткань путём плотного перекрёстного переплетения идущих рядами продольных поперечных нитей наткать наткать ткать ткать выткать выткать': '113006-V',
#  'сидеть подходить одежде сидеть сидеть': '121198-V',
#  'изрезать расчленить пересеченными линиями изрезывать изрезывать изрезать изрезать': '126326-V',
#  'приложить применить действие прилагать помещение какого объекта рядом вместе приложить приложить прилагать прилагать': '140496-V',
#  'вытряхнуть выбросить уронить вытряхнуть вытряхнуть вытряхивать вытряхивать вытрясти вытрясти': '116221-V',
#  'лидировать первенствовать ведущее положение позиция лидера лидировать лидировать первенствовать первенствовать': '137950-V',
#  'коммунальный платеж платить жилищно коммунальные услуги платить жилищно коммунальный услуга платить платить жкх платить жкх платить платить жку платить жку платить оплатить жкх оплатить жкх оплатить оплатить жилищно коммунальные услуги оплатить жилищно коммунальный услуга оплатить оплатить коммунальные услуги оплатить коммунальный услуга оплатить платить коммунальные услуги платить коммунальный услуга платить платить услуги жкх платить услуга жкх платить': '4659-V',
#  'осушение земель осушить осушить осушать осушать': '3844-V',
#  'отравить ядовитым веществом нанести вред живому организму действием яда ядовитого вещества попавшего внутрь пищу дыхание отравить ядовитым веществом отравить ядовитый вещество отравить травить травить отравить отравить отравлять отравлять потравить потравить': '111606-V',
#  'считаться выяснять отношения сводить счеты сводить счеты сводить свести счеты свести счеты свести посчитаться посчитаться считаться считаться': '150723-V',
#  'понижение цен уменьшились цены уменьшиться цена уменьшиться понизиться цене понизиться цена понизиться цены упали цена упасть упасть уменьшиться цене уменьшиться цена уменьшиться дешеветь дешеветь снизились цены снизиться цена снизиться понизились цены понизиться цена понизиться стать дешевле стать дешевле стать понизить цены понизить цена понизить уменьшать цены уменьшать цена уменьшать снизиться цене снизиться цена снизиться цены понизились цена понизиться понизиться подешеветь подешеветь упали цены упасть цена упасть понижать цены понижать цена понижать уменьшить цены уменьшить цена уменьшить становиться дешевле становиться дешевле становиться цены снизились цена снизиться снизиться снижать стоимость снижать стоимость снижать упасть цене упасть цена упасть удешевляться удешевляться снизить стоимость снизить стоимость снизить снизить цену снизить цена снизить цены уменьшились цена уменьшиться уменьшиться снижать цену снижать цена снижать потерять цене потерять цена потерять': '8529-V',
#  'разнести распространить распространить многих разнести разнести разносить разносить': '120458-V',
#  'прободение прободать прободать': '128351-V',
#  'расшатать разболтать делать неустойчивым расшатывать расшатывать расшатать расшатать раскачать раскачать разболтать разболтать разбалтывать разбалтывать раскачивать раскачивать': '140719-V',
#  'вздремнуть вздремнуть вздремнуть': '129800-V',
#  'галлюцинация расстройство восприятия выражающееся обманном появлении зрительных слуховых ощущений наличия реальных объектов являющееся следствием нарушения деятельности мозга психических заболеваниях травмах галлюцинировать галлюцинировать': '123908-V',
#  'втиснуть впихнуть впихивать впихивать втиснуть втиснуть впихнуть впихнуть втискивать втискивать': '125769-V',
#  'впитаться жидкости газе попадать проникать внутрь какого твёрдого тела поверхность распределяясь объёме всасываться поглощаться вбираться впитаться впитаться впитываться впитываться': '115965-V',
#  'концертная деятельность выступать концертах давать концерты выступать концертом выступать концерт выступать выступить концертом выступить концерт выступить дать концерт дать концерт дать давать концерт давать концерт давать выступить концерте выступить концерт выступить концертировать концертировать выступать концерте выступать концерт выступать': '9588-V',
#  'пробраться трудом проникнуть помощью уловок ухищрений попасть проникнуть куда добиться получить какой статус пробираться пробираться трудом проникнуть труд проникнуть проникнуть пробраться пробраться': '117932-V',
#  'растянуть времени растянуть времени растянуть время растянуть растягивать времени растягивать время растягивать растягиваться растягиваться растянуть растянуть': '121061-V',
#  'отложить яйца личинки яйцах икре некоторых животных выводить организма оставляя продолжения потомства отложить отложить откладывать откладывать класть класть': '116173-V',
#  'зудеть испытывать зуд испытывать зуд испытывать зуд испытывать зудеть зудеть зудить зудить': '120185-V',
#  'произвол своеволие самовластие чинить произвол чинить произвол чинить хотят воротят хотеть воротить хотеть': '134174-V',
#  'обозреть анализировать исследовать рассмотреть речи статье обозреть обозреть обозревать обозревать': '150069-V',
#  'выехать показаться появиться где откуда перемещаясь транспортном средстве выезжать выезжать выехать выехать': '143777-V',
#  'отработать кончить работать отработать отработать отслужить отслужить': '137320-V',
#  'раскрутить сделать известным продвигать деятеля массовой культуры делать популярным раскрутить раскрутить раскручивать раскручивать': '147492-V',
#  'оживиться наполниться движением деятельностью выйти состояния вялости апатии безразличия оживляться оживляться ожить ожить оживать оживать оживиться оживиться': '118862-V',
#  'сузить уменьшить ширину делать уже уменьшать ширину уменьшать ширину уменьшать ширина уменьшать суживать суживать уменьшать ширину уменьшать ширина уменьшать сузить сузить сужать сужать уменьшить ширину уменьшить ширина уменьшить уменьшить ширину уменьшить ширина уменьшить': '127237-V',
#  'передать воспроизвести изобразить воспроизвести передать передать передавать передавать': '113973-V',
#  'грех поступок нарушение действием словом мыслью воли бога религиозно нравственных предписаний правил нагрешить нагрешить грешить грешить совершить грех совершить грех совершить совершать грех совершать грех совершать согрешить согрешить': '125957-V',
#  'перечертить скопировать чертеж счертить счертить перечерчивать перечерчивать счерчивать счерчивать скопировать чертеж скопировать чертеж скопировать перечертить перечертить': '111627-V',
#  'заманить завлечь привлекая заставлять прийти куда оказаться где тянуть тянуть тянуть магнитом тянуть магнит тянуть поманить поманить заманивать заманивать завлечь завлечь заманить заманить завлекать завлекать': '118595-V',
#  'контратака контратаковать контратаковать': '117523-V',
#  'подсудность подлежать рассмотрению суде подлежать рассмотрение суд подлежать': '7660-V',
#  'обилие изобилие большое количество полный достаток изобиловать изобиловать': '131736-V',
#  'анализ рассмотрение метод исследования объектов путём выделения рассмотрения отдельных частей анализировать анализировать провести анализ провести анализ провести': '106897-V',
#  'классифицировать классифицировать классифицировать расклассифицировать расклассифицировать': '120139-V',
#  'отстрелить оторвать отстреливать отстреливать отстрелить отстрелить': '115551-V',
#  'защита воздействия ограждение внешней угрозы нападений других нежелательных воздействий защищать воздействия защищать воздействие защищать защищать защищать защититься воздействия защититься воздействие защититься защищаться защищаться защищаться воздействия защищаться воздействие защищаться защитить воздействия защитить воздействие защитить защитить защитить защититься защититься': '140492-V',
#  'отопление обогрев помещения отапливать отапливать отопить отопить': '144-V',
#  'тайное голосование голосовать тайно голосовать тайно голосовать': '1567-V',
#  'додуматься прийти выводу размышляя прийти какой мысли какому выводу решению додумываться додумываться додуматься додуматься': '130882-V',
#  'знак рукой подать знак подать знак подать': '118639-V',
#  'сговор соглашение договор несколькими субъектами совместных действиях взаимных вступать сговор вступать сговор вступать': '107467-V',
#  'вспыхнуть волнения радости внезапно быстро краснеть покрываться румянцем волнения стыда радости итп вспыхнуть вспыхнуть вспыхивать вспыхивать залиться краской залиться краска залиться залиться румянцем залиться румянец залиться заливаться краской заливаться краска заливаться': '130184-V',
#  'нокаут отправить нокаут отправить нокаут отправить послать нокаут послать нокаут послать нокаутировать нокаутировать': '126847-V',
#  'скатить вниз катя заставляя катиться спускать вниз перемещать откуда скатить скатить скатывать скатывать скатить вниз скатить вниз скатить': '115157-V',
#  'газировать насытить газом насыщение газом газировать газировать': '117660-V',
#  'экономия экономное расходование сокращать расход переставать тратить начинать тратить меньше раньше расходовать экономно расходовать экономно расходовать экономить экономить сэкономить сэкономить': '112734-V',
#  'переехать проехав задавить раздавить двигаясь транспортном средстве раздавить переезжать переезжать переехать переехать': '137397-V',
#  'падать резко понижаться уменьшение снижение величины катиться вниз катиться вниз катиться резко понижаться резко понижаться понижаться покатиться вниз покатиться вниз покатиться упасть упасть обрушиться обрушиться обвалиться обвалиться войти пике войти пике войти падать падать резко понизиться резко понизиться понизиться': '144032-V',
#  'ввести привести завести внутрь завести внутрь завести заводить внутрь заводить внутрь заводить вводить внутрь вводить внутрь вводить ввести ввести заводить заводить ввести внутрь ввести внутрь ввести завести завести вводить вводить': '129720-V',
#  'шептаться зашептаться зашептаться шептаться шептаться шушукаться шушукаться шепотом переговариваться шепот переговариваться переговариваться пошептаться пошептаться перешептываться перешептываться перешепнуться перешепнуться': '117878-V',
#  'истощить крайне ослабить доводить крайней слабости делать тощим лишать сил обескровить обескровить истощать истощать истощить истощить обескровливать обескровливать': '118663-V',
#  'взаимодополнение взаимодополнять взаимодополнять': '142435-V',
#  'правонарушение нарушение норм права действующих законов нарушить закон нарушить закон нарушить переступать закон переступать закон переступать нарушать законодательство нарушать законодательство нарушать содеянный содеянный нарушать закон нарушать закон нарушать переступить закон переступить закон переступить правонарушающий правонарушающий преступить закон преступить закон преступить закон писан закон писать писать': '647-V',
#  'пропить деньги имущество пропить пропить пропить деньги пропить деньги пропить пропивать пропивать пропивать деньги пропивать деньги пропивать': '117172-V',
#  'округлить сделать круглым округлить округлить округлять округлять сделать округлым сделать округлый сделать сделать круглым сделать круглый сделать': '123558-V',
#  'списать переписать сдирать сдирать содрать содрать списать списать списывать списывать': '154876-V',
#  'высылка наказание выслать выслать высылать высылать': '137167-V',
#  'некомплект недоукомплектовать недоукомплектовать': '142076-V',
#  'патрулирование несение патрульной службы регулярный осмотр целью охраны поддержания порядка патрулировать патрулировать': '3977-V',
#  'отстрочить отстрачивать отстрачивать отстрочить отстрочить': '117016-V',
#  'разоблачить раскрыть открывать обнаруживать чьи злоупотребления тайные замыслы враждебные предосудительные действия планы устанавливать вскрывать делать известным неправильность враждебность разоблачить разоблачить разоблачать разоблачать вывести чистую воду вывести чистый вода вывести': '120088-V',
#  'благотворное действие благотворно подействовать благотворный подействовать благотворный благотворно влиять благотворный влиять благотворный': '153116-V',
#  'вооружить обеспечить снабжать оснащать орудиями материалами средствами какой деятельности вооружить вооружить вооружать вооружать': '140473-V',
#  'разбиться насмерть разбиться насмерть разбиться насмерть разбиться разбиваться насмерть разбиваться насмерть разбиваться насмерть разбиться насмерть разбиться разбиться убиться убиться': '153793-V',
#  'выбить получить трудом получать трудом применив силу принуждения выбить трудом выбить труд выбить выбить выбить выбивать выбивать вырвать трудом вырвать труд вырвать выбивать трудом выбивать труд выбивать вырывать вырывать вырывать трудом вырывать труд вырывать вырвать вырвать': '130336-V',
#  'нашуметь привлечь всеобщее внимание нагреметь нагреметь нашуметь нашуметь': '120140-V',
#  'завести механизм устройство закручивание пружины приводящей действие механизм нибудь приведение движение заводить заводить завестись завестись заводить механизм заводить механизм заводить заводиться заводиться механизм заводится механизм заводиться заводиться завести завести завести механизм завести механизм завести': '131121-V',
#  'выставить пост охрану выставить пост выставить пост выставить выставлять выставлять выставить выставить выставить охрану выставить охрана выставить': '154282-V',
#  'скрыться поля зрения стать невидным незаметным исчезнуть поля зрения спрятаться прятаться прятаться скрыться глаз скрыться глаз скрыться скрываться скрываться скрыться поля зрения скрыться поле зрение скрыться скрываться глаз скрываться глаз скрываться скрыться скрыться скрыться виду скрыться вид скрыться спрятаться спрятаться': '146698-V',
#  'затруднить обременить поручением просьбой затруднять затруднять доставлять затруднение доставлять затруднение доставлять утруждать утруждать затруднить затруднить доставить затруднение доставить затруднение доставить': '118199-V',
#  'кочевой образ жизни кочевничество образ жизни скотоводов аридной засушливой зоны бродячих охотников собирателей кочевать кочевать': '121506-V',
#  'малодушничать малодушничать малодушничать смалодушничать смалодушничать': '132237-V',
#  'прекращение брака прекратить брак прекратить брак прекратить': '145354-V',
#  'кастрация оскопление оскопить оскопить кастрировать кастрировать выхолащивать выхолащивать выхолостить выхолостить оскоплять оскоплять': '126124-V',
#  'подтолкнуть слегка толкнуть подтолкнуть подтолкнуть подталкивать подталкивать': '114119-V',
#  'колебательное изменение повторяющийся процесс изменения течением времени значения физической величины среднего значения заколебаться заколебаться поколебаться поколебаться колебаться колебаться': '149802-V',
#  'плакать радости плакать радости плакать радость плакать': '153001-V',
#  'отпустить перестать нажимать отпустить отпустить отпускать отпускать': '154736-V',
#  'дармоедничать тунеядствовать тунеядствовать дармоедничать дармоедничать': '135439-V',
#  'консультироваться консультироваться консультироваться получать консультацию получать консультация получать проконсультироваться проконсультироваться получить консультацию получить консультация получить': '121343-V',
#  'натереть навести лоск начищать блеска вытирая втирая придавать лоск натереть натереть навести лоск навести лоск навести наводить лоск наводить лоск наводить натирать натирать': '111785-V',
#  'дотащиться добраться доползти доползти дотащиться дотащиться доползать доползать дотаскиваться дотаскиваться': '130948-V',
#  'материть материть материть обругать матом обругать мат обругать обматерить обматерить выматерить выматерить': '143610-V',
#  'мониторинг постоянное наблюдение каким процессом целью изучения динамики проверки соответствия мониторить мониторить': '7752-V',
#  'учинить совершить неблагоприятное делать совершать устраивать обычно неприятное нежелательное учинить учинить учинять учинять': '141680-V',
#  'просчитаться ошибиться счете обсчитываться обсчитываться просчитаться просчитаться обсчитаться обсчитаться обчесться обчесться просчитываться просчитываться ошибиться счете ошибиться счет ошибиться': '141490-V',
#  'аукцион публичная продажа вещи лицу предложившему наивысшую цену продать молотка продать молоток продать уйти молотка уйти молоток уйти пойти молотка пойти молоток пойти': '574-V',
#  'нарушить преступить несоблюдение законов правил создание помех сбоев допустить нарушение допустить нарушение допустить преступить преступить соблюсти соблюсти соблюсти нарушать нарушать переступать переступать переступить переступить преступать преступать соблюдать соблюдать соблюдать допускать нарушение допускать нарушение допускать нарушить нарушить': '122242-V',
#  'распознать всматриваясь разглядеть различить узнать распознаваться распознаваться распознать распознать различать различать различить различить распознавать распознавать': '111591-V',
#  'переоценить неверно оценить оценивать слишком высоко выше следует переоценивать переоценивать переоценить переоценить': '151498-V',
#  'окрикнуть окрикнуть окрикнуть окрикивать окрикивать': '107159-V',
#  'опыление растений опылять опылять опылиться опылиться опыляться опыляться': '131136-V',
#  'обогнать движении опережать соревнуясь беге ходьбе ином движении обходить обходить перегонять перегонять обогнать обогнать обогнать движении обогнать движение обогнать обойти обойти опережать движении опережать движение опережать перегнать перегнать совершать обгон совершать обгон совершать опередить движении опередить движение опередить опережать опережать совершить обгон совершить обгон совершить обгонять обгонять опередить опередить': '127231-V',
#  'узнать знакомое узнать распознать узнать знакомое узнать знакомый узнать узнавать узнавать узнаваться узнаваться признавать признавать признать признать узнать узнать': '117369-V',
#  'очиститься освободиться загрязняющего заслоняющего освобождаться ненужного нежелательного дурного вредного очищаться очищаться очиститься очиститься': '121544-V',
#  'прийти чувство приходить чувство приходить чувство приходить прийти прийти прийти прийти чувство прийти чувство прийти приходить приходить приходить': '128299-V',
#  'гипнотизировать введение человека гипнотическое состояние загипнотизировать загипнотизировать гипнотизировать гипнотизировать': '114482-V',
#  'оснастить снабдить оснастить оснастить дооснащать дооснащать уснащать уснащать вооружиться вооружиться дооснастить дооснастить оснащаться оснащаться оснащать оснащать уснастить уснастить': '112630-V',
#  'отбывание наказания мотать срок мотать срок мотать отбыть срок заключения отбыть срок заключение отбыть отсидеть отсидеть отсиживать отсиживать отбыть наказание отбыть наказание отбыть отбыть срок наказания отбыть срок наказание отбыть отсидеть свой срок отсидеть свой срок отсидеть отсиживать срок отсиживать срок отсиживать отбыть срок отбыть срок отбыть отбывать наказание отбывать наказание отбывать отбывать срок отбывать срок отбывать отсидеть срок отсидеть срок отсидеть сидеть решеткой сидеть решетка сидеть': '1848-V',
#  'инструктировать проинструктировать проинструктировать давать инструкцию давать инструкция давать дать инструкцию дать инструкция дать инструктировать инструктировать': '116909-V',
#  'переоснастить переоснастить переоснастить переоснащать переоснащать': '139346-V',
#  'опознание следственное действие провести опознание провести опознание провести опознавать опознавать опознать опознать предъявить опознания предъявить опознание предъявить опознать личность опознать личность опознать предъявлять опознания предъявлять опознание предъявлять проводить опознание проводить опознание проводить': '8269-V',
#  'орошение искусственное орошение земель испытывающих недостаток влаги повышения плодородия орошать орошать орошаться орошаться оросить оросить': '495-V',
#  'осмотреть оглядеть смотреть разных всех сторон окидывать взглядом осматривать осмотреть осмотреть обозревать обозревать оглядывать оглядывать обвести глазами обвести глаз обвести обсматривать обсматривать окинуть окинуть окидывать взором окидывать взор окидывать озирать озирать окинуть взором окинуть взор окинуть обводить взором обводить взор обводить обвести взором обвести взор обвести окинуть глазами окинуть глаз окинуть обсмотреть обсмотреть обвести взглядом обвести взгляд обвести осматривать осматривать окидывать взглядом окидывать взгляд окидывать оглядеть оглядеть окидывать окидывать окинуть взглядом окинуть взгляд окинуть обводить взглядом обводить взгляд обводить обводить глазами обводить глаз обводить обозреть обозреть': '106902-V',
#  'оттереть отчистить счищая стирая оттирать оттирать оттереть оттереть': '130966-V',
#  'вылететь появиться быстро перемещаясь внезапно появиться выскочить вылететь вылететь повылетать повылетать вылетать вылетать': '117616-V',
#  'свидетельствовать служить свидетельством давать представление передавать информацию говорить однозначно говорить однозначный говорить свидетельствовать свидетельствовать говорить говорить значить значить означать означать служить свидетельством служить свидетельство служить': '106868-V',
#  'капитализация дохода превращать превратить прибавочную стоимость капитал капитализировать капитализировать': '8240-V',
#  'расклеить разных местах прикрепить предметы некоторого набора множестве различных мест помощи клея расклеить разных местах расклеить разный место расклеить расклеивать расклеивать расклеивать разных местах расклеивать разный место расклеивать расклеить расклеить': '114959-V',
#  'отклеиться отклеиться отклеиться расклеиваться расклеиваться отклеиваться отклеиваться расклеиться расклеиться': '146464-V',
#  'смутить привести смущение вызывать чувство неловкости приводить замешательство конфузить конфузить оконфузить оконфузить привести смущение привести смущение привести привести замешательство привести замешательство привести смущать смущать приводить смущение приводить смущение приводить оконфуживать оконфуживать сконфузить сконфузить смутить смутить приводить замешательство приводить замешательство приводить': '117302-V',
#  'завещать оставить завет оставить завет оставить завет оставить завещать завещать': '148390-V',
#  'переварить сварить заново переваривать переваривать переварить заново переварить заново переварить переварить переварить сварить заново сварить заново сварить': '112383-V',
#  'трепетать колебаться дрожать быть охваченным мелкой дрожью колебаться дрожать затрепетать затрепетать трепетать трепетать': '114585-V',
#  'всосать вобрать засосать засосать всосать всосать засосать засосать засосать засасывать засасывать всасываться всасываться всасывать всасывать': '115224-V',
#  'прожить провести время провести время живя проживать проживать прожить прожить': '123465-V',
#  'выпустить закончить обучение научить полностью довести обучение конца какого предела доучивать доучивать выпустить выпустить выпускать выпускать доучить доучить закончить обучение закончить обучение закончить': '137279-V',
#  'уплотнение жильцов уплотнять уплотнять уплотнить жильцов уплотнить жилец уплотнить уплотнять жильцов уплотнять жилец уплотнять уплотнить уплотнить': '129364-V',
#  'шумная возня беспокойно суетливо напряжением двигаться завозиться завозиться возиться возиться развозиться развозиться повозиться повозиться': '130102-V',
#  'опустошить привести запустение делать безлюдным нежилым приводить запустение приводить запустение приводить привести опустошению привести опустошение привести привести запустение привести запустение привести опустошить опустошить приводить опустошению приводить опустошение приводить опустошать опустошать': '144583-V',
#  'тащить извлекать таща извлечь переместить наружу тащить тащить потащить потащить вытащить вытащить таскать таскать': '118326-V',
#  'воплотиться получить воплощение идеях планах замыслах получать выражение конкретных делах формах осуществляться действительности претворяться жизнь воплотиться воплотиться отлиться отлиться отливаться отливаться получить воплощение получить воплощение получить получать воплощение получать воплощение получать воплощаться воплощаться': '133439-V',
#  'стабилизировать привести устойчивое состояние приведение устойчивое состояние состояние устойчивости постоянства застабилизировать застабилизировать стабилизировать стабилизировать стабилизовать стабилизовать': '129209-V',
#  'сажать помещать длительное время помещать размещать какую поверхность место назначения сажать сажать посадить посадить': '113944-V',
#  'собрать снять сорвать пособирать пособирать собрать собрать убрать убрать насобирать насобирать собирать собирать': '120231-V',
#  'запуск космических аппаратов запустить космический аппарат запустить космический аппарат запустить запускать космический аппарат запускать космический аппарат запускать': '131907-V',
#  'эмиссия ценных бумаг выпускать ценные бумаги выпускать ценный бумага выпускать выпускать эмиссионные ценные бумаги выпускать эмиссионный ценный бумага выпускать выпустить ценные бумаги выпустить ценный бумага выпустить': '2075-V',
#  'переспросить спрашивать раз снова обращаться вопросом спросить раз спросить раз спросить спрашивать раз спрашивать раз спрашивать переспрашивать переспрашивать переспросить переспросить': '111813-V',
#  'отсыпать высыпать отсыпать отсыпать': '152588-V',
#  'принудить заставить силой заставить сделать заставлять заставлять додавить додавить понудить понудить принуждать принуждать заставить заставить понуждать понуждать принудить принудить': '106817-V',
#  'ложь неправда утверждение соответствующее истине высказанное таком виде сознательно соответствовать действительности соответствовать действительность соответствовать': '107178-V',
#  'вертеть стороны сторону повертеть повертеть вертеть стороны сторону вертеть сторона сторона вертеть вертеть вертеть': '118532-V',
#  'перебросить промахнуться перебросить перебросить перекидывать перекидывать перебрасывать перебрасывать перекинуть перекинуть': '137813-V',
#  'телефонизация устанавливать телефон устанавливать телефон устанавливать оборудовать телефоном оборудовать телефон оборудовать проводить телефон проводить телефон проводить проводить телефонную линию проводить телефонный линия проводить подключить телефонной линии подключить телефонный линия подключить телефонизировать телефонизировать установить телефон установить телефон установить провести телефон провести телефон провести подключать телефонной линии подключать телефонный линия подключать': '2564-V',
#  'заключить закончить завершить заключить заключить заключать заключать': '113051-V',
#  'золочение поверхности золотить золотить вызолотить вызолотить позолотить позолотить раззолотить раззолотить вызолачивать вызолачивать': '111330-V',
#  'томиться изнывать изнывать маяться маяться истомиться истомиться измаяться измаяться помаяться помаяться томиться томиться изныть изныть промаяться промаяться': '117325-V',
#  'отогнуться отвернуться сторону наружу отгибаться отгибаться отогнуться отогнуться': '133474-V',
#  'жонглирование предметами жонглировать жонглировать жонглировать предметами жонглировать предмет жонглировать': '121172-V',
#  'рубить дом сруб срубить срубить рубить сруб рубить сруб рубить рубить рубить рубить дом рубить дом рубить срубить дом срубить дом срубить': '120338-V',
#  'истечение срока окончание какого срока отрезка времени истек срок истекать срок истекать истекать истекать истечь истечь': '112154-V',
#  'резать порезать разделить нибудь режущим части вскрыть какую нибудь часть тела нарушить целость какой нибудь ткани нибудь режущим дорезать дорезать разрезать части разрезать часть разрезать порезать порезать разрезать разрезать резать части резать часть резать нарезаться нарезаться нарезать нарезать резать резать': '107412-V',
#  'съехать скатиться спуститься вниз процессе езды съезжать вниз съезжать вниз съезжать съехать вниз съехать вниз съехать съезжать съезжать съехать съехать скатываться скатываться скатиться скатиться': '117061-V',
#  'блистать отличаться блистать блистать блестеть блестеть блеснуть блеснуть возвышаться возвышаться заблистать заблистать показать лучшей стороны показать лучший сторона показать': '118233-V',
#  'головная боль голова раскалывается голова раскалываться раскалываться голова трещит голова трещать трещать голова болит голова болеть болеть': '137794-V',
#  'тащиться волочиться тянуться волочиться земле другой поверхности волочиться волочиться волочиться земле волочиться земля волочиться волочься волочься волочься земле волочься земля волочься тянуться тянуться тащиться тащиться влачиться влачиться': '130132-V',
#  'задувка доменной печи задуть печь задуть печь задуть задувать задувать задувать печь задувать печь задувать задуть задуть': '131220-V',
#  'занести движении занести сторону занести сторона занести заносить движении заносить движение заносить заносить сторону заносить сторона заносить заноситься заноситься занести занести заносить заносить занести движении занести движение занести': '150091-V',
#  'наркомания болезненное иногда непреодолимое влечение пристрастие систематическому употреблению наркотиков приводящее тяжёлым нарушениям физических психических функций организма употреблять наркотики употреблять наркотик употреблять': '2635-V',
#  'перекатить перекатить перекатить перекатывать перекатывать': '116149-V',
#  'вживить организм вводить инородное тело живую ткань приживания вживить вживить вживлять вживлять вживить организм вживить организм вживить': '125596-V',
#  'прострел поясницы прострелить прострелить': '110238-V',
#  'сообщиться передаться перейти перейти передаться передаться передаваться передаваться сообщаться сообщаться сообщиться сообщиться переходить переходить': '120762-V',
#  'констатировать установить устанавливать удостоверить удостоверять несомненность наличие нибудь констатировать констатировать': '118108-V',
#  'разогнаться ускориться беге езде набирать увеличивать скорость взять разгон взять разгон взять разгоняться разгоняться разогнаться разогнаться брать разгон брать разгон брать': '128663-V',
#  'выпутать освободить выпутать выпутать распутать распутать выпутывать выпутывать распутывать распутывать': '130468-V',
#  'разлиться выйти берегов выступая берегов распространяться новые места заливая своими водами лишнее пространство выходить берегов реке озере разлиться разлиться выходить берегов выходить берег выходить разливаться разливаться выйти берегов выйти берег выйти': '121279-V',
#  'окружить людьми окружать окружать окружить окружить окружить людьми окружить человек окружить': '133325-V',
#  'оценка качества оценивать качество оценивать качество оценивать оценить качество оценить качество оценить': '149274-V',
#  'татуировать набивать тату набивать тату набивать наколоть татуировку наколоть татуировка наколоть делать тату делать тату делать делать татуировку делать татуировка делать сделать татуировку сделать татуировка сделать наколоть тату наколоть тату наколоть делать наколку делать наколка делать татуировать татуировать сделать наколку сделать наколка сделать вытатуировать вытатуировать сделать тату сделать тату сделать': '121550-V',
#  'отучить привычки отучивать отучивать отучить привычки отучить привычка отучить отучать отучать отучать привычки отучать привычка отучать отучить отучить': '116385-V',
#  'господствовать преобладать господствовать господствовать иметь перевес иметь перевес иметь превалировать превалировать доминировать доминировать главенствовать главенствовать преобладать преобладать довлеть довлеть брать верх брать верх брать царить царить царствовать царствовать являться доминантой являться доминанта являться': '106948-V',
#  'реакция нейтрализации подвергать подвергнуть химической реакции которой раствор становится нейтральным теряя кислотные щелочные свойства нейтрализовать нейтрализовать': '146178-V',
#  'нумеровать обозначение цифрами номерами перенумеровывать перенумеровывать занумеровать занумеровать поставить номер поставить номер поставить ставить номер ставить номер ставить пронумеровать пронумеровать нумеровать нумеровать перенумеровать перенумеровать': '115791-V',
#  'встреча собрание собрание устраиваемое целью знакомства обсуждения встретиться встретиться': '106783-V',
#  'мыслительный процесс процесс обработки информации мозгом человека уточнение модели действительности сознании раскинуть умом раскинуть ум раскинуть раскинуть мозгами раскинуть мозг раскинуть мыслить мыслить размышлять размышлять помыслить помыслить поразмышлять поразмышлять мысли текут мысль течь течь соображать соображать подумывать подумывать шевелить мозгами шевелить мозг шевелить подумать подумать думать думать думаться думаться': '106467-V',
#  'обступить охватить мыслях чувствах обступить обступить обступать обступать': '146706-V',
#  'значиться числиться быть находиться какой должности каком положении каких условиях числиться числиться значиться составе значиться состав значиться состоять состоять считаться считаться числиться составе числиться состав числиться значиться значиться состоять составе состоять состав состоять': '123423-V',
#  'поощрить сочувствием поддержкой одобрением наградой побудить поддержать поощрять поощрять поощрить поощрить': '113220-V',
#  'заступиться вступаться защищать стоять горой стоять гора стоять заступиться заступиться вступиться вступиться давать обиду давать обида давать заступаться заступаться вступаться вступаться': '118617-V',
#  'квашение наквашивать наквашивать заквашивать заквашивать проквашивать проквашивать наквасить наквасить заквасить заквасить сквасить сквасить проквасить проквасить квасить квасить': '118732-V',
#  'драть сдирать отрывать срывать отдирать отдирать сдирать сдирать драть драть надирать надирать отодрать отодрать надрать надрать ободрать ободрать обдирать обдирать содрать содрать': '114075-V',
#  'производство вооружений разрабатывать оружие разрабатывать оружие разрабатывать выпускать оружие выпускать оружие выпускать создавать вооружение создавать вооружение создавать изготовлять оружие изготовлять оружие изготовлять создавать оружие создавать оружие создавать производить вооружения производить вооружение производить производить оружие производить оружие производить выпускать вооружения выпускать вооружение выпускать': '1689-V',
#  'парковка автотранспорта парковать парковаться постановка автомобиля стоянку парковать парковать припарковать припарковать запарковать запарковать припарковывать припарковывать': '112697-V',
#  'разъяснеться прояснеться разъяснеть разъяснеть распогодиться распогодиться разъясняться разъясняться разъясниться разъясниться проясняться проясняться разъяснеться разъяснеться прояснеться прояснеться прояснеть прояснеть проясниться проясниться': '128676-V',
#  'политическая борьба бороться власть бороться власть бороться': '8089-V',
#  'слабеть стать тугим ослабляться ослабляться ослабнуть ослабнуть ослабиться ослабиться ослабеть ослабеть слабнуть слабнуть слабеть слабеть': '128593-V',
#  'урчать угрожающий протяжный низкий звук издаваемый животным напоминающий урчать урчать проурчать проурчать ворчать ворчать заурчать заурчать бурчать бурчать': '114745-V',
#  'перебрать пересмотреть разобрать перебирать перебирать перебрать перебрать': '120040-V',
#  'удвоить увеличить два раза умножить два удвоить удвоить удваивать удваивать увеличить два раза увеличить два раза увеличить': '107405-V',
#  'считать определять количество сосчитать определить количество сумму счесть счесть досчитать досчитать просчитать просчитать определить количество определить количество определить пересчитывать пересчитывать насчитывать насчитывать насчитать насчитать посчитать посчитать определять количество определять количество определять просчитывать просчитывать сосчитать сосчитать досчитывать досчитывать считать считать пересчитать пересчитать': '106885-V',
#  'примчать довезти доставить домчать примчать примчать домчать домчать доносить доносить донести донести': '140663-V',
#  'утащить увезти увести желанию утаскивать утаскивать утащить утащить': '124871-V',
#  'выдвинуться вперед наружу выдвигаться выдвигаться выдвинуться выдвинуться': '124720-V',
#  'дрожать колебаться дрожать дрожать трястись трястись тряхнуться тряхнуться затрястись затрястись подрагивать подрагивать плясать плясать дрогнуть дрогнуть задрожать задрожать': '114517-V',
#  'обвал цен цены рухнули цена рухнуть рухнуть обвалить цену обвалить цена обвалить обвалилась цена обвалиться цена обвалиться': '149461-V',
#  'загнуть согнуть согнуть изогнуть перегнуть перегнуть перегибать перегибать загибать загибать загнуть загнуть': '117196-V',
#  'обжечь повредить огнем причинить ожоги боль повреждать огнем горячим жгучим обжигать ожечь ожечь повредить огнем повредить огонь повредить повреждать огнем повреждать огонь повреждать обжечь обжечь обжигать обжигать': '114419-V',
#  'концентрирование веществ насыщать сгущать какой раствор путём удаления избытка растворителя концентрировать концентрировать': '146156-V',
#  'накалить обстановку накалить обстановку накалить обстановка накалить взрывать обстановку взрывать обстановка взрывать раскалять раскалять накалить ситуацию накалить ситуация накалить накалять накалять накалить накалить взрывать ситуацию взрывать ситуация взрывать раскалить раскалить взорвать ситуацию взорвать ситуация взорвать взорвать обстановку взорвать обстановка взорвать': '127073-V',
#  'выделиться отличиться обладать особыми качествами отличаясь окружающих выделиться числа выделиться число выделиться выделяться выделяться выделиться выделиться выделяться других выделяться другой выделяться отличиться отличиться выделяться числа выделяться число выделяться выделиться других выделиться другой выделиться отличаться отличаться': '117846-V',
#  'покрыться накрыть закрыть сверху прикрываться прикрываться укрыться укрыться накрыть накрыть накрыть накрываться накрываться покрыться покрыться укрываться укрываться прикрыться прикрыться покрываться покрываться накрыться накрыться': '113782-V',
#  'кучковаться собираться кучками собираться кучками собираться кучка собираться кучковаться кучковаться': '143715-V',
#  'валютный обмен купить валюту купить валюта купить конвертировать валюту конвертировать валюта конвертировать купить иностранную валюту купить иностранный валюта купить продать валюту продать валюта продать продавать иностранную валюту продавать иностранный валюта продавать приобретать валюту приобретать валюта приобретать покупать иностранную валюту покупать иностранный валюта покупать конвертировать иностранную валюту конвертировать иностранный валюта конвертировать покупать валюту покупать валюта покупать приобрести валюту приобрести валюта приобрести продать иностранную валюту продать иностранный валюта продать продавать валюту продавать валюта продавать': '8334-V',
#  'управление устройством управлять управлять управляться управляться править править поуправлять поуправлять': '106614-V',
#  'разрешить позволить дать разрешение выразить согласие совершение какого действия позволить позволить предоставить разрешение предоставить разрешение предоставить разрешить разрешить позволяться позволяться разрешить разрешить разрешить разрешать разрешать дозволять дозволять дозволить дозволить дать разрешение дать разрешение дать давать разрешение давать разрешение давать позволять позволять дозволяться дозволяться': '107175-V',
#  'высечь камня высекаться высекаться высекать высекать высечь камня высечь камень высечь высечь высечь': '125883-V',
#  'шарахаться избегать шарахаться шарахаться': '141455-V',
#  'валяться месте валяться валяться валяться месте валяться место валяться проваляться проваляться': '121209-V',
#  'согнать места сгонять сгонять согнать места согнать место согнать сгонять места сгонять место сгонять согнать согнать': '135163-V',
#  'коммерциализация внедрение коммерческих отношений перевод переход коммерческую основу превращать источник дохода превращать источник доход превращать извлекать коммерческую выгоду извлекать коммерческий выгода извлекать коммерциализировать коммерциализировать коммерциализовать коммерциализовать извлекать прибыль извлекать прибыль извлекать': '2466-V',
#  'зеленеть покрыться свежей травой зазеленеть зазеленеть зеленеть зеленеть позеленеть позеленеть': '114627-V',
#  'отнести доставить сносить сносить снести снести относить относить отнести отнести отнести другое место отнести другой место отнести': '120820-V',
#  'дать слово выступления передать слово передать слово передать предоставлять слово предоставлять слово предоставлять давать слово давать слово давать предоставить слово предоставить слово предоставить передавать слово передавать слово передавать дать слово выступления дать слово выступление дать слово предоставить слово предоставить предоставить дать слово дать слово дать': '149980-V',
#  'размахнуться удара броска отвести руку реже ногу сторону назад удара толчка броска сделать взмах замах размахнуться удара размахнуться удар размахнуться размахнуться размахнуться размахиваться размахиваться': '131401-V',
#  'эмиссия физический процесс излучать излучить испускать испустить элементарные частицы ионы эмитировать эмитировать': '137377-V',
#  'предъявить предъявить претензию предъявить претензия предъявить предъявить предъявить предъявлять предъявлять': '117036-V',
#  'зашить соединить швом скрепляться швом соединять швом зашить зашить зашивать зашивать зашиваться зашиваться': '111575-V',
#  'автоматизация применение автоматов других технических средств экономико математические методов частичного полного освобождения человека непосредственного участия производственных иных процессах автоматизировать автоматизировать': '924-V',
#  'дрожать всем телом дрожать всем телом дрожать весь тело дрожать колотить колотить колотить колотить колотить трястись всем телом трястись весь тело трястись': '151738-V',
#  'рябь глазах пестрит глазах пестрить глаз пестрить рябить рябить глазах пестрит глаз пестрить пестрить рябить глазах рябить глаз рябить': '134701-V',
#  'примешать добавить смешивая добавлять присоединять примешивать примешивать примешать примешать': '111607-V',
#  'подпустить добавить добавлять куда дополнять подпускать подпускать подпустить подпустить': '141441-V',
#  'голосование процедура способ принятия решения группой людей котором общее мнение формулируется подсчёта голосов членов группы иным способом отдавать голос отдавать голос отдавать подать голос подать голос подать доголосовать доголосовать отдать свой голос отдать свой голос отдать наголосовать наголосовать проголосовать проголосовать отдавать свой голос отдавать свой голос отдавать проголосоваться проголосоваться отдать голос отдать голос отдать подать свой голос подать свой голос подать отголосовать отголосовать вотировать вотировать голосовать голосовать': '10119-V',
#  'засветиться загореться начать испускать свет начать светить засветиться засветиться разгореться разгореться зажечься зажечься загореться загореться начать светиться начать светиться начать зажигаться зажигаться загораться загораться засиять засиять просиять просиять засветить засветить разгораться разгораться': '131552-V',
#  'унести взять взяв подняв нагрузив удалять откуда перемещать куда уходя брать уносить уносить унести унести уноситься уноситься уносить уносить уносить унести унести унести': '110913-V',
#  'прослезиться выступили слезы выступить слеза выступить прослезиться прослезиться слеза прошибла слеза прошибать прошибать слезы накатились слеза накатиться накатиться вышибать слезу вышибать слеза вышибать мог сдержать слез мочь сдержать слеза мочь выступали слезы выступать слеза выступать вышибить слезу вышибить слеза вышибить слезы наворачиваются слеза наворачиваться наворачиваться': '118861-V',
#  'премировать награждать наградить премией премировать премировать': '117052-V',
#  'выдворение страны насильственное переселение групп населения целых народов этнической родины территории длительного проживания депортировать депортировать выдворить пределы страны выдворить предел страна выдворить выслать иностранцев выслать иностранец выслать выдворять страны выдворять страна выдворять высылать страны высылать страна высылать депортировать родину депортировать родина депортировать выслать страны выслать страна выслать выдворить страны выдворить страна выдворить': '3833-V',
#  'крутить скручивать крутя круговым вращением завинтить ввести внутрь ввернуть покрутить покрутить закрутить закрутить скрутить скрутить скручивать скручивать закручивать закручивать крутить крутить': '134447-V',
#  'расписать присочинить красочно рассказать похвалить разрисовывать разрисовывать расписать расписать расписывать расписывать разрисовать разрисовать': '138409-V',
#  'цветение воды водоёме покрываться ряской тиной зацветать зацветать цвести цвести': '131627-V',
#  'пренебрегать проявить высокомерное отношение действие пренебрегать пренебречь отсутствие внимания кому надлежащей заботливости ком проявлять пренебрежение проявлять пренебрежение проявлять нос воротить нос воротить воротить пренебрегать пренебрегать проявить пренебрежение проявить пренебрежение проявить смотреть сверху вниз смотреть сверху вниз смотреть воротить нос воротить нос воротить пренебречь пренебречь': '117049-V',
#  'заметить обнаружить обнаружить обратить внимание увидеть увидеть вскрывать вскрывать ускользнуть внимания ускользнуть внимание ускользнуть обнаруживать обнаруживать высветить высветить замечать замечать засечь засечь обнаружить обнаружить заприметить заприметить выявить выявить вскрыть вскрыть подмечать подмечать примечать примечать засекать засекать высвечивать высвечивать выявлять выявлять приметить приметить подметить подметить заметить заметить': '117371-V',
#  'аннексия территории аннексировать аннексировать': '120619-V',
#  'отселить отселить отселить отселять отселять': '115545-V',
#  'клепать соединять заклепать заклепать склепать склепать склепывать склепывать клепать клепать заклепывать заклепывать': '109163-V',
#  'церемониться считаться церемониться церемониться': '144638-V',
#  'уткнуться погрузиться какое занятие утыкнуться носом утыкнуться нос утыкнуться уткнуться уткнуться зарыться зарыться утыкаться утыкаться зарываться зарываться': '129398-V',
#  'переход следующий уровень перейти следующий уровень перейти следующий уровень перейти переходить следующий уровень переходить следующий уровень переходить': '153243-V',
#  'сработаться достичь сработанности срабатываться срабатываться сработаться сработаться': '121461-V',
#  'улетучивание жидкости улетучиться улетучиться улетучиваться улетучиваться': '135460-V',
# ...
#  'валять боку бок валять боку бок валять бок бок валять валять валять': '123757-V',
#  'подтянуться руках выполнить подтягивание держась руками сгибая локтях поднять своё тело вверх висячем положении подтянуться руках подтянуться рука подтянуться подтянуться подтянуться подтягиваться подтягиваться': '121256-V',
#  'испытания жизни тяжёлая судьба страдание испытания нести свой крест нести свой крест нести': '142535-V',
#  'обесцениться утратить ценность уменьшение ценности утрачивать ценность утрачивать ценность утрачивать обесцениться обесцениться обесцениваться обесцениваться утратить ценность утратить ценность утратить утрачивать свою ценность утрачивать свой ценность утрачивать утратить свою ценность утратить свой ценность утратить': '132999-V',
#  'высечь искру огонь высечь высечь высечь искру высечь искра высечь высекаться высекаться высекать высекать высечь огонь высечь огонь высечь высекать огонь высекать огонь высекать высекать искру высекать искра высекать': '152655-V',
#  'вывернуть вывихнуть выкручивать выкручивать выкрутить выкрутить вывернуть вывернуть выворачивать выворачивать выворотить выворотить вывертывать вывертывать': '125782-V',
#  'бредить мечтать бредить бредить': '117397-V',
#  'разъехаться двигаясь навстречу зацепить друг друга разъезжаться разъезжаться разъехаться разъехаться': '134426-V',
#  'тереть порошок тереть порошок тереть порошок тереть растереть растереть растирать растирать растереть порошок растереть порошок растереть': '115940-V',
#  'горячее водоснабжение снабжать горячей водой снабжать горячий вода снабжать': '3722-V',
#  'пищать говорить пискляво запищать запищать пищать пищать пропищать пропищать': '107101-V',
#  'навязать заставить взять навязывать навязывать навязать навязать': '132740-V',
#  'перебежать перейти сторону противника предательски переходить сторону противника предаваться кому перекидываться перекидываться перейти сторону перейти сторона перейти перебегать перебегать перебежать сторону перебежать сторона перебежать переметнуться сторону переметнуться сторона переметнуться перейти сторону противника перейти сторона противник перейти переметываться переметываться перебежать врагу перебежать враг перебежать перебежать сторону врага перебежать сторона враг перебежать перебежать перебежать переметнуться переметнуться перекинуться перекинуться переметнуться стан переметнуться стан переметнуться': '120177-V',
#  'послать бросить направить направлять запускать бросать слать слать послать послать посылать посылать': '118269-V',
#  'касаться иметь отношение обращаться реагировать определённым образом иметь отношение иметь отношение иметь относиться относиться затронуть затронуть коснуться коснуться затрагивать затрагивать задеваться задеваться касаться касаться': '137400-V',
#  'приобретение юридического лица приобрести фирму приобрести фирма приобрести приобретать бизнес приобретать бизнес приобретать приобрести предприятие приобрести предприятие приобрести приобрести компанию приобрести компания приобрести приобретать фирму приобретать фирма приобретать приобрести бизнес приобрести бизнес приобрести приобретать предприятие приобретать предприятие приобретать приобретать компанию приобретать компания приобретать': '150980-V',
#  'принимать пищу процесс принятия пищи подъесть подъесть едать едать покушать покушать кушать кушать подкрепиться подкрепиться скушать скушать трапезничать трапезничать потреблять пищу потреблять пища потреблять принимать пищу принимать пища принимать сожрать сожрать пожрать пожрать доесть доесть съедать съедать подкрепляться подкрепляться подъедать подъедать проесть проесть съесть съесть поесть поесть откушать откушать употреблять пищу употреблять пища употреблять доедать доедать жрать жрать': '106934-V',
#  'влипнуть попасть липкое влипнуть влипнуть влипать влипать': '117068-V',
#  'дергать беспокоить мешать дергать дергать': '120489-V',
#  'обязать наложить обязанность налагать какие обязанности заставлять принуждать делать обязывать обязывать вменить вменить вменять обязанность вменять обязанность вменять вменять вменять накладывается обязательство накладываться обязательство накладываться наложить обязанность наложить обязанность наложить обязать обязать накладывается обязанность накладываться обязанность накладываться вменить обязанность вменить обязанность вменить': '116820-V',
#  'отнекиваться сказать сказать сказать сказать ответить ответить ответить отнекиваться отнекиваться': '124786-V',
#  'приписать подписать написать внизу добавить снизу уже написанному подписывать подписывать приписывать приписывать дописывать дописывать приписать приписать подписать подписать дописать дописать': '111984-V',
#  'голубеть становиться голубым голубеть голубеть поголубеть поголубеть': '110890-V',
#  'залиться внутрь проникнуть куда влиться жидкости залиться внутрь залиться внутрь залиться залиться залиться заливаться заливаться': '115724-V',
#  'затихнуть гаснуть глохнуть терять силу ослабевать сходить прекращаться кончаться исчезать замереть замереть угаснуть угаснуть спадать спадать угасать угасать затихнуть затихнуть тухнуть тухнуть потухать потухать приутихнуть приутихнуть замолкать замолкать умолкнуть умолкнуть глохнуть глохнуть тихнуть тихнуть погаснуть погаснуть замирать замирать поутихнуть поутихнуть стихать стихать заглохнуть заглохнуть затихать затихать смолкать смолкать утихать утихать стихнуть стихнуть погасать погасать утихнуть утихнуть умолкать умолкать гаснуть гаснуть': '114833-V',
#  'перекрыть газ воду перекрыть перекрыть перекрывать перекрывать перекрыть вентиль перекрыть вентиль перекрыть перекрывать вентиль перекрывать вентиль перекрывать перекрывать трубу перекрывать труба перекрывать перекрыть трубу перекрыть труба перекрыть перекрываться перекрываться': '152637-V',
#  'править руководить править править': '123566-V',
#  'лишение права лишать права лишать право лишать лишить права лишить право лишить': '143921-V',
#  'выгрести удалить выгрести выгрести выгребать выгребать': '137549-V',
#  'попрать пренебрегая грубо нарушить унизить попрать попрать попирать попирать': '116946-V',
#  'решить принять решение обдумывать ситуацию формулируя определённый вывод делая заключение вырабатывая план какого действия решить решить разрешать разрешать решиться решиться разрешить разрешить принять решение принять решение принять решать решать решаться решаться принимать решение принимать решение принимать разрешаться разрешаться разрешиться разрешиться': '107489-V',
#  'вынести наружу неся переместить наружу пределы выносить руках выносить рука выносить вынести вынести выносить выносить вынести руках вынести рука вынести выносить наружу выносить наружу выносить выноситься выноситься вынести наружу вынести наружу вынести': '116725-V',
#  'насесть просьбой наседать требованием наседать требование наседать приставать просьбой приставать просьба приставать наседать наседать пристать просьбой пристать просьба пристать наседать просьбой наседать просьба наседать': '120349-V',
#  'травмировать наносить травму получать травму получать травма получать травмировать травмировать наносить травму наносить травма наносить получить травму получить травма получить нанести травму нанести травма нанести': '112731-V',
#  'закупать перекупать слишком долго купая причинить вред кому закупать закупать перекупать перекупать': '141459-V',
#  'хмуриться хмурить брови насупливаться насупливаться хмуриться хмуриться нахмуривать нахмуривать скукситься скукситься хмурить лоб хмурить лоб хмурить нахмурить брови нахмурить бровь нахмурить нахмурить нахмурить нахохлиться нахохлиться кукситься кукситься хмурить хмурить набычиваться набычиваться нахмуриться нахмуриться бычиться бычиться нахмуриваться нахмуриваться набычиться набычиться хмурить брови хмурить бровь хмурить накукситься накукситься хохлиться хохлиться насупиться насупиться насупливать насупливать насупить насупить хмурить лицо хмурить лицо хмурить': '118509-V',
#  'навредить навредить навредить навредить вредить вредить вредить': '154983-V',
#  'несанкционированный доступ информации получать информацию незаконно получать информация незаконно получать получить информацию незаконно получить информация незаконно получить незаконно получать сведения незаконно получать сведение получать получить сведения незаконно получить сведение незаконно получить незаконно получить информацию незаконно получить информация получить получать сведения незаконно получать сведение незаконно получать незаконно получить сведения незаконно получить сведение получить незаконно получать информацию незаконно получать информация получать': '124022-V',
#  'проникнуть распространиться распространяться укрепляться быту общественном сознании проникать проникать проникнуть проникнуть': '139810-V',
#  'распространение слухов распространять сплетни поговаривать поговаривать посплетничать посплетничать перемывать кости перемывать кость перемывать распустить слухи распустить слухи распустить распространять слухи распространять слух распространять ходят слухи ходить слух ходить поползли слухи поползти слух поползти сплетничать сплетничать распространять сплетни распространять сплетня распространять судачить судачить поползли разговоры поползти разговор поползти распускать сплетни распускать сплетня распускать распустить сплетни распустить сплетня распустить распускать слухи распускать слух распускать насплетничать насплетничать посудачить посудачить перемывать косточки перемывать косточка перемывать передавать слухи передавать слух передавать поползти поползти': '127120-V',
#  'колебаться сомневаться начать испытывать сомнения неуверенность заколебаться заколебаться колебаться колебаться задумываться задумываться поколебаться поколебаться колебаться нерешительности колебаться нерешительность колебаться задуматься задуматься': '117493-V',
#  'повышение цен стать дороже вырасти цене цены повысились цена повыситься повыситься цены увеличились цена увеличиться увеличиться подскочили цены подскочить цена подскочить увеличить цены увеличить цена увеличить подорожать подорожать повысились цены повыситься цена повыситься повышать цены повышать цена повышать удорожать удорожать выросли цены вырасти цена вырасти цены поднялись цена подняться подняться поднимать цены поднимать цена поднимать дорожать дорожать удорожаться удорожаться удорожиться удорожиться повысить цены повысить цена повысить взвинчивать цены взвинчивать цена взвинчивать удорожить удорожить задирать цену задирать цена задирать вздорожать вздорожать цены растут цена расти расти вырасти цене вырасти цена вырасти задрать цену задрать цена задрать вздернуть цены вздернуть цена вздернуть вздувать цены вздувать цена вздувать поднять цены поднять цена поднять вздернулись цены вздернуться цена вздернуться цены выросли цена вырасти вырасти цены вздернулись цена вздернуться вздернуться взвинтить цену взвинтить цена взвинтить стать дороже стать дороже стать вздуть цены вздуть цена вздуть прибавить цене прибавить цена прибавить цены подскочили цена подскочить подскочить растут цены расти цена расти поднялись цены подняться цена подняться увеличиться цене увеличиться цена увеличиться повыситься цене повыситься цена повыситься увеличивать цены увеличивать цена увеличивать цены возросли цена возрасти возрасти становиться дороже становиться дороже становиться прибавлять цене прибавлять цена прибавлять цены взлетели цена взлететь взлететь': '2214-V',
#  'отстрелиться резко отделиться отделяться использованием пиротехнических устройств отстрелиться отстрелиться отстреливаться отстреливаться': '120143-V',
#  'ускорить придвинуть срок ускорять ускорять сокращать срок сокращать срок сокращать придвинуть срок придвинуть срок придвинуть придвигать срок придвигать срок придвигать ускорить ускорить сократить срок сократить срок сократить ускориться ускориться ускорить наступление ускорить наступление ускорить': '112606-V',
#  'отдуваться другого отдуваться отдуваться': '127327-V',
#  'удовлетворить отвечать требованиям оказаться вполне отвечающим соответствующим устраивать устраивать уложиться уложиться укладываться укладываться удовлетворять удовлетворять соответствовать требованиям соответствовать требование соответствовать удовлетворить удовлетворить устроить устроить удовлетворять требованиям удовлетворять требование удовлетворять отвечать требованиям отвечать требование отвечать отвечать отвечать': '114046-V',
#  'подсказать напомнить подсказывать подсказывать подсказать подсказать подсказываться подсказываться': '112297-V',
#  'приобрести свойство стать носителем каких свойств получить какие свойства приобрести приобрести приобретать новое качество приобретать новый качество приобретать приобретать свойство приобретать свойство приобретать приобретать приобретать приобрести новое качество приобрести новый качество приобрести приобрести свойство приобрести свойство приобрести заиметь заиметь сделаться сделаться': '111489-V',
#  'перестрахование перестраховывать перестраховывать перестраховать перестраховать': '7667-V',
#  'отнести числу отнести какой категории относить числу относить число относить относить относить отнести числу отнести число отнести отнести категории отнести категория отнести отнести отнести относить категории относить категория относить подвести подвести подводить подводить': '118736-V',
#  'презирать относиться презрением пренебрегать считать недостойным внимания незначащим обдать презрением обдать презрение обдать презирать презирать облить презрением облить презрение облить относиться презрением относиться презрение относиться': '117045-V',
#  'пронять сильно подействовать пронимать пронимать пробрать пробрать пронять пронять прошибать прошибать пробирать пробирать прошибить прошибить': '118602-V',
#  'политизация придать придавать политический характер кому политизировать политизировать заполитизировать заполитизировать': '137706-V',
#  'донять допечь допечь допечь донять донять допекать допекать донимать донимать преследовать преследовать': '130934-V',
#  'грызться кусать друг друга погрызться погрызться грызться грызться': '125969-V',
#  'охрана лесов охранять леса охранять лес охранять защищать леса защищать лес защищать охранять деревья охранять дерево охранять защищать деревья защищать дерево защищать сохранить леса сохранить лес сохранить сохранять леса сохранять лес сохранять': '3956-V',
#  'мятеж стихийное восстание бунтовать бунтовать': '4281-V',
#  'снизиться ухудшиться снижаться снижаться снизиться снизиться': '140756-V',
#  'содействие оказывать помощь содействие кому помогать содействовать содействовать содействовать посодействовать посодействовать поспособствовать поспособствовать способствовать способствовать': '112905-V',
#  'нормализовать приход приведение норму нормализовывать нормализовывать нормализовать нормализовать': '143859-V',
#  'конкретизация давать дать конкретное выражение делать сделать конкретным уточнять уточнить конкретизировать конкретизировать': '126040-V',
#  'призвать позвать явиться делать обращаться кому предложением требованием вести определённым образом бросить клич бросить клич бросить бросать клич бросать клич бросать кидать клич кидать клич кидать призывать призывать кинуть клич кинуть клич кинуть призвать призвать': '118313-V',
#  'выпустить дать выйти дать возможность разрешение покинуть какое помещение ограниченное пространство выпустить выпустить пустить пустить выпускать выпускать пускать пускать': '114519-V',
#  'пребывать состоянии находиться быть каком положении состоянии быть быть находиться состоянии находиться состояние находиться побыть побыть находиться находиться быть состоянии быть состояние быть пребывать пребывать состоять состоять пребывать состоянии пребывать состояние пребывать состоять состоянии состоять состояние состоять побывать состоянии побывать состояние побывать побыть состоянии побыть состояние побыть': '150230-V',
#  'распугать разогнать распугать распугать распугивать распугивать': '128783-V',
#  'видеть иметь зрение обладать зрением зрительной способностью обладать зрением обладать зрение обладать видеть видеть иметь зрение иметь зрение иметь': '151329-V',
#  ...}

# %%
make_sentences_params
# Out:
# {'ruthes_name': True,
#  'definition': True,
#  'senses_names': True,
#  'senses_lemmas': True,
#  'senses_main_word': True,
#  'sep': ' '}

# %%
get_synset_words(ruwordnet, '124987-N',
                       norm_params=norm_fn_params,
                       make_sent_params=make_sentences_params,
                       norm_function=normalize_ma,
                      )
# Out:
# ['однокашник',
#  'товарищ учебе',
#  'товарищ обучению',
#  'воспитанию',
#  'соученица',
#  'соученица',
#  'товарищ учебе',
#  'товарищ учеба',
#  'товарищ',
#  'однокашница',
#  'однокашница',
#  'соученик',
#  'соученик',
#  'однокашник',
#  'однокашник']

# %%
get_synset_words(ruwordnet, '103748-N',
                 norm_params=norm_fn_params,
                 make_sent_params=make_sentences_params,
                 norm_function=normalize_ma,
                )
# Out:
# ['гамбург', 'гамбург', 'гамбург']

# %%
get_synset_words(ruwordnet, '2642-N',
                 norm_params=norm_fn_params,
                 make_sent_params=make_sentences_params,
                 norm_function=normalize_ma,
                )
# Out:
# ['санкт петербург',
#  'санкт петербург',
#  'санкт петербург',
#  'северная столица',
#  'северный столица',
#  'столица',
#  'ленинград',
#  'ленинград',
#  'питер',
#  'питер',
#  'петроград',
#  'петроград',
#  'северная пальмира',
#  'северный пальмира',
#  'пальмира',
#  'спб',
#  'спб',
#  'петербург',
#  'петербург']

# %% [markdown]
# ### PROCESS WORDS FOR TEST SETS

# %%
def process_words(words, 
                  params_grid,
                  prefix, 
                  nouns, 
                  model,
                  algo='default',
                  out_dir='/tmp'):
    for params in tqdm(params_grid()):
        start = time.time()
        p1,p2,p3,k,topn,account_gold,norm_function = params['p1'],params['p2'],params['p3'],\
                                                     params['k'],params['topn'],params['account_gold'],\
                                                     params['normalize_func']
        
        pos = "N" if nouns else "V"
        
        norm_fn_params_list = {'out_of_vocab2synonym',
                               'sort',
                               'unique',
                               'lower',
                               'min_word_len',
                               'punct_symbols',
                               'prepositions',
                               'restrict_tags',
                               'accept_tags',
                               'ma'
                               }
        norm_fn_params = {param_name: params[param_name] 
                          for param_name in norm_fn_params_list
                          if param_name in params}
        if nouns:
            make_sentences_params = {'ruthes_name': True,
                                     'definition': False,
                                     'senses_names': True,
                                     'senses_lemmas': False,
                                     'senses_main_word': False,
                                     'sep': ' '
                                    }
        else:
            make_sentences_params = {'ruthes_name': True,
                                     'definition': True,
                                     'senses_names': True,
                                     'senses_lemmas': True,
                                     'senses_main_word': True,
                                     'sep': ' '
                                    }
        
        if nouns:
            word2parents = read_train_dataset('data/training_data/synsets_nouns.tsv', ruwordnet)
            gold_synsetid2parents = read_gold_dataset('data/training_data/synsets_nouns.tsv')
        else:
            word2parents = read_train_dataset('data/training_data/synsets_verbs.tsv', ruwordnet)
            gold_synsetid2parents = read_gold_dataset('data/training_data/synsets_verbs.tsv')
        
        synsetstr2id = dict()
        synsetstr2vector = dict()
        for synset in ruwordnet.synsets_list:
            if synset['part_of_speech'] != pos:
                continue

            synset_words, vector = get_synset_str_and_vector(ruwordnet, synset['id'], 
                                                             norm_params=norm_fn_params,
                                                             make_sent_params=make_sentences_params,
                                                             norm_function=norm_function,
                                                             model=model)
            synsetstr = ' '.join(synset_words)
            if synsetstr in synsetstr2id:
                logging.error(f"Duplicate synset_str.{synset['id'],synsetstr2id[synsetstr]}:'{synsetstr}'")
            synsetstr2id[synsetstr] = synset['id']
            synsetstr2vector[synsetstr] = vector

#         print (len(synsetstr2vector))
                              
        example_vector = None
        for _,v in synsetstr2vector.items():
            example_vector = v
            break

        ruwordnet_matrix = np.zeros((len(synsetstr2vector),example_vector.shape[0]),
                                     example_vector.dtype)

        for i, (s, v) in enumerate(synsetstr2vector.items()):
            ruwordnet_matrix[i] = v
#         print (ruwordnet_matrix.shape)
                
        
        result = collections.defaultdict(list)
        for w in words:
            hypernyms = get_top_hyperomyns_counter(w, 
                                                   k=k, 
                                                   p1=p1,p2=p2,p3=p3, 
                                                   account_gold=account_gold,
                                                   ruwordnet_matrix=ruwordnet_matrix,
                                                   gold_synsetid2parents=gold_synsetid2parents,
                                                   synsetstr2id=synsetstr2id,
                                                   synsetstr2vector=synsetstr2vector,
                                                   model=model,
                                                   ruwordnet=ruwordnet
                                                  )
            result[w] = [h for h,rate in hypernyms.most_common()][:topn]
            
        
        curr_time ='_'.join(str(datetime.now()).split()).replace(':','')
        out_file  = f'{prefix}_{k}_{topn}_{p1}_{p2}_{p3}_{account_gold}_{curr_time}'
        out_file  = os.path.join(out_dir, out_file)
                              
        with open(out_file+'.json', 'w') as of_json:
            params_out = {p: str(params[p]) for p in params.keys()}
            json.dump(params_out,fp=of_json, indent=4)

        save_to_file(result, out_file+'.tsv', 
                     ruwordnet)
                              
        
        end = time.time()
        logging.info(f"Saved {out_file}.")
        logging.info(f"Spent time: {end - start} secs ({(end - start)/60.} minutes).")

# %%
public_words = list()
private_words = list()

def load_words(nouns):
    global public_words
    global private_words
#     if nouns:
#         print (ruwordnet.get_synset_senses_list('126551-N'))
#     else:
#         print (ruwordnet.get_synset_senses_list('124595-V'))

#     if nouns:
#         print(len([s for s in ruwordnet.synsets_list if s['part_of_speech']=='N']))
#     else:
#         print(len([s for s in ruwordnet.synsets_list if s['part_of_speech']=='V']))
    if nouns:
        with open('data/public_test/nouns_public.tsv', 'r') as f:
            public_words = [l.strip().lower() for l in f.readlines()]
        with open('data/private_test/nouns_private.tsv', 'r') as f:
            private_words = [l.strip().lower() for l in f.readlines()]
    else:
        with open('data/public_test/verbs_public.tsv', 'r') as f:
            public_words = [l.strip().lower() for l in f.readlines()]
        with open('data/private_test/verbs_private.tsv', 'r') as f:
            private_words = [l.strip().lower() for l in f.readlines()]

# %% [markdown]
# ### PUBLIC NOUNS

# %%
nouns = True 
load_words(nouns)
for model_name, model in modelname2model.items():
    process_words(public_words, 
                  params_grid, 
                  '_'.join(('public_nouns',common_prefix, model_name)),
                  nouns,
                  model=model, 
                  out_dir=results_dir
                  )
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# 2020-03-23 20:53:44,066 INFO: Saved results/res_lower_true/public_nouns_lower_true_ft.cc.ru.300_10_10_0.1_1.0_1.0_False_2020-03-23_205343.984475.
# 2020-03-23 20:53:44,067 INFO: Spent time: 61.66870307922363 secs (1.0278117179870605 minutes).
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# 2020-03-23 20:54:47,453 INFO: Saved results/res_lower_true/public_nouns_lower_true_tayga_none_fasttextcbow_300_10_2019_10_10_0.1_1.0_1.0_False_2020-03-23_205447.372180.
# 2020-03-23 20:54:47,454 INFO: Spent time: 63.36373972892761 secs (1.0560623288154602 minutes).
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# 2020-03-23 20:55:51,139 INFO: Saved results/res_lower_true/public_nouns_lower_true_araneum_none_fasttextcbow_300_5_2018_10_10_0.1_1.0_1.0_False_2020-03-23_205551.057730.
# 2020-03-23 20:55:51,140 INFO: Spent time: 63.661333084106445 secs (1.0610222180684408 minutes).

# %% [markdown]
# ### PRIVATE NOUNS

# %%
nouns = True 
load_words(nouns)
for model_name, model in modelname2model.items():
    process_words(private_words, 
                  params_grid, 
                  '_'.join(('private_nouns',common_prefix, model_name)),
                  nouns,
                  model=model,
                  out_dir=results_dir
                 )
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# 2020-03-23 20:57:33,267 INFO: Saved results/res_lower_true/private_nouns_lower_true_ft.cc.ru.300_10_10_0.1_1.0_1.0_False_2020-03-23_205733.154668.
# 2020-03-23 20:57:33,268 INFO: Spent time: 102.0984275341034 secs (1.7016404589017233 minutes).
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# 2020-03-23 20:59:16,622 INFO: Saved results/res_lower_true/private_nouns_lower_true_tayga_none_fasttextcbow_300_10_2019_10_10_0.1_1.0_1.0_False_2020-03-23_205916.509092.
# 2020-03-23 20:59:16,622 INFO: Spent time: 103.32964515686035 secs (1.7221607526143392 minutes).
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %% [markdown]
# ### PUBLIC VERBS

# %%
nouns = False 
load_words(nouns)
for model_name, model in modelname2model.items():
    process_words(public_words, 
                  params_grid, 
                  '_'.join(('public_verbs',common_prefix, model_name)),
                  nouns,
                  model=model,
                  out_dir=results_dir
                 )

# %% [markdown]
# ### PRIVATE VERBS

# %%
nouns = False 
load_words(nouns)
for model_name, model in modelname2model.items():
    process_words(private_words,
                  params_grid,
                  '_'.join(('private_verbs',common_prefix, model_name)),
                  nouns,
                  model=model,
                  out_dir=results_dir
                 )

# %% [markdown]
# # ELMO

# %%
params

# %%
elmo_work_dir = '_'.join(('data/elmo_vectors',common_prefix))
elmo_model_dir = 'data/rusvectores_models/199'

# %%
! mkdir -p {elmo_work_dir}

# %%
# %%time

def prepare_elmo_data(nouns):
    if nouns:
        make_sentences_params = {'ruthes_name': True,
                                 'definition': False,
                                 'senses_names': True,
                                 'senses_lemmas': False,
                                 'senses_main_word': False,
                                 'sep': ' '
                                }
    else:
        make_sentences_params = {'ruthes_name': True,
                                 'definition': True,
                                 'senses_names': True,
                                 'senses_lemmas': True,
                                 'senses_main_word': True,
                                 'sep': ' '
                                }
    norm_fn_params_list = {'out_of_vocab2synonym',
                           'sort',
                           'unique',
                           'lower',
                           'min_word_len',
                           'punct_symbols',
                           'prepositions',
                           'restrict_tags',
                           'accept_tags',
                           'ma'
                           }
    norm_fn_params = {param_name: params[param_name] 
                      for param_name in norm_fn_params_list
                      if param_name in params}


    synsetid2sentence = dict()
    for synset in ruwordnet.synsets_list:
        synset_id=synset['id']
        if not ((nouns and synset_id.endswith('N')) or 
                (not nouns and synset_id.endswith('V') )):
            continue

        words = get_synset_words(ruwordnet, synset_id,
                                 norm_params=norm_fn_params,
                                 make_sent_params=make_sentences_params,
                                 norm_function=normalize_ma
                                )
        sentence = ' '.join(words).strip()
        synsetid2sentence[synset_id] = sentence

    if nouns:
        fname = os.path.join(elmo_work_dir,'sentences_N.txt')
        fname_s = os.path.join(elmo_work_dir, 'synsetids_N.txt')
    else:
        fname = os.path.join(elmo_work_dir,'sentences_V.txt')
        fname_s = os.path.join(elmo_work_dir,'synsetids_V.txt')

    with open(fname, 'w') as f:
        f.writelines([sent+'\n' for s_id, sent in synsetid2sentence.items()])
    with open(fname_s, 'w') as f:
        f.writelines([s_id+'\n' for s_id, sent in synsetid2sentence.items()])

prepare_elmo_data(True)
prepare_elmo_data(False)

# %%
# %%time
nouns = True 
load_words(nouns)
with open(os.path.join(elmo_work_dir,'public_nouns.txt'), 'w') as f:
    f.writelines([w.lower()+'\n' for w in public_words])
with open(os.path.join(elmo_work_dir,'private_nouns.txt'), 'w') as f:
    f.writelines([w.lower()+'\n' for w in private_words])
nouns = False 
load_words(nouns)
with open(os.path.join(elmo_work_dir,'public_verbs.txt'), 'w') as f:
    f.writelines([w.lower()+'\n' for w in public_words])
with open(os.path.join(elmo_work_dir,'private_verbs.txt'), 'w') as f:
    f.writelines([w.lower()+'\n' for w in private_words])

# %%
elmo_work_dir

# %%
elmo_model_dir

# %% [markdown]
# #### Get elmo vectors

# %%
! cd simple_elmo/ && ./make_elmo_vectors_ruwordnet.sh ../{elmo_work_dir} ../{elmo_model_dir} && cd ../

# %%
# %%time
ruwordnet_matrix = np.load(os.path.join(elmo_work_dir,
                                        'sentences_N_elmo_avg_vectors_199.npy')
                          )
ruwordnet_matrix.shape

# %%
public_nouns_matrix = np.load(os.path.join(elmo_work_dir,
                                           'public_nouns_elmo_avg_vectors_199.npy')
                             )
public_nouns_matrix[0]

# %%
with open(os.path.join(elmo_work_dir,'synsetids_N.txt'), 'r') as f:
    synset_ids_N = [l.strip() for l in f.readlines()]

# %%
# !head -2 {elmo_work_dir}/sentences_N.txt

# %%
# !head -10 {elmo_work_dir}/public_nouns.txt

# %%
get_top(public_nouns_matrix[5], ruwordnet_matrix, synset_ids_N)

# %%
get_top(public_nouns_matrix[0], ruwordnet_matrix, synset_ids_N)

# %%
def process_words_elmo_199(public, 
                       params_grid,
                       prefix, 
                       nouns,
                       elmo_work_dir,
                       out_dir='/tmp'):
    
    for params in tqdm(params_grid()):
        start = time.time()
        p1,p2,p3,k,topn,account_gold,norm_function = params['p1'],params['p2'],params['p3'],\
                                                     params['k'],params['topn'],params['account_gold'],\
                                                     params['normalize_func']
        
        pos = "N" if nouns else "V"
        
        if nouns:
            word2parents = read_train_dataset('data/training_data/synsets_nouns.tsv', ruwordnet)
            gold_synsetid2parents = read_gold_dataset('data/training_data/synsets_nouns.tsv')
        else:
            word2parents = read_train_dataset('data/training_data/synsets_verbs.tsv', ruwordnet)
            gold_synsetid2parents = read_gold_dataset('data/training_data/synsets_verbs.tsv')
            
        if nouns:
            ruwordnet_matrix = np.load(os.path.join(elmo_work_dir,'sentences_N_elmo_avg_vectors_199.npy'))
            with open(os.path.join(elmo_work_dir, 'synsetids_N.txt'), 'r') as f:
                synset_ids = [l.strip() for l in f.readlines()]
            with open(os.path.join(elmo_work_dir, 'sentences_N.txt'), 'r') as f:
                sentences = [l.strip() for l in f.readlines()]
        else:
            ruwordnet_matrix = np.load(os.path.join(elmo_work_dir,'sentences_V_elmo_avg_vectors_199.npy'))
            with open(os.path.join(elmo_work_dir,'synsetids_V.txt'), 'r') as f:
                synset_ids = [l.strip() for l in f.readlines()]
            with open(os.path.join(elmo_work_dir,'sentences_V.txt'), 'r') as f:
                sentences = [l.strip() for l in f.readlines()]

        if nouns and public:
            words_matrix = np.load(os.path.join(elmo_work_dir,'public_nouns_elmo_avg_vectors_199.npy'))
            with open(os.path.join(elmo_work_dir,'public_nouns.txt'), 'r') as f:
                words = [l.strip() for l in f.readlines()]
        elif nouns and (not public):
            words_matrix = np.load(os.path.join(elmo_work_dir,'private_nouns_elmo_avg_vectors_199.npy'))
            with open(os.path.join(elmo_work_dir,'private_nouns.txt'), 'r') as f:
                words = [l.strip() for l in f.readlines()]
        elif (not nouns) and public:
            words_matrix = np.load(os.path.join(elmo_work_dir,'public_verbs_elmo_avg_vectors_199.npy'))
            with open(os.path.join(elmo_work_dir,'public_verbs.txt'), 'r') as f:
                words = [l.strip() for l in f.readlines()]
        elif (not nouns) and (not public):
            words_matrix = np.load(os.path.join(elmo_work_dir,'private_verbs_elmo_avg_vectors_199.npy'))
            with open(os.path.join(elmo_work_dir,'private_verbs.txt'), 'r') as f:
                words = [l.strip() for l in f.readlines()]
            
        
        synsetstr2id = dict()
        synsetstr2vector = dict()
        
        for synsetstr, synsetid, synsetvector in zip(sentences, synset_ids, ruwordnet_matrix):
            synsetstr2id[synsetstr] = synsetid
            synsetstr2vector[synsetstr] = synsetvector
        
        result = collections.defaultdict(list)
        for w, v in zip(words, words_matrix):
            hypernyms = get_top_hyperomyns_counter_v(v, 
                                                     k=k, 
                                                     p1=p1,p2=p2,p3=p3, 
                                                     account_gold=account_gold,
                                                     ruwordnet_matrix=ruwordnet_matrix,
                                                     gold_synsetid2parents=gold_synsetid2parents,
                                                     synsetstr2id=synsetstr2id,
                                                     synsetstr2vector=synsetstr2vector,
                                                     ruwordnet=ruwordnet
                                                    )
            result[w] = [h for h,rate in hypernyms.most_common()][:topn]
            
        
        curr_time ='_'.join(str(datetime.now()).split()).replace(':','')
        out_file  = f'{prefix}_{k}_{topn}_{p1}_{p2}_{p3}_{account_gold}_{curr_time}'
        out_file  = os.path.join(out_dir, out_file)
                              
        with open(out_file+'.json', 'w') as of_json:
            params_out = {p: str(params[p]) for p in params.keys()}
            json.dump(params_out,fp=of_json, indent=4)

        save_to_file(result, out_file+'.tsv', 
                     ruwordnet)
                              
        
        end = time.time()
        logging.info(f"Saved {out_file}.")
        logging.info(f"Spent time: {end - start} secs ({(end - start)/60.} minutes).")

# %%
# %%time
public=True
nouns=True
process_words_elmo_199(public, params_grid, 
                       '_'.join(('public_nouns_elmo_199',common_prefix)), 
                       nouns, elmo_work_dir, out_dir=results_dir)

# %%
# %%time
public=True
nouns=False
process_words_elmo_199(public, params_grid, 
                       '_'.join(('public_verbs_elmo_199',common_prefix)),
                       nouns, elmo_work_dir, out_dir=results_dir)

# %%
# %%time
public=False
nouns=True
process_words_elmo_199(public, params_grid, 
                       '_'.join(('private_nouns_elmo_199',common_prefix)),
                       nouns, elmo_work_dir, out_dir=results_dir)

# %%
# %%time
public=False
nouns=False
process_words_elmo_199(public, params_grid, 
                       '_'.join(('private_verbs_elmo_199',common_prefix)),
                       nouns, elmo_work_dir, out_dir=results_dir)
